# %% [markdown]
# # Seaborn Tutorial
# This notebook covers essential concepts of **Seaborn**, a Python library for statistical data visualization.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
sns.set_theme(style="darkgrid")

# %% [markdown]
# ## Loading Sample Data
# Seaborn provides built-in datasets for easy visualization.

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Bar Plot
# A bar plot is useful for comparing categorical data.

# %%
sns.barplot(x='day', y='total_bill', data=df)
plt.title('Average Bill per Day')
plt.show()

# %% [markdown]
# ## Histogram & KDE Plot
# Seaborn provides `histplot` and `kdeplot` for distribution visualization.

# %%
sns.histplot(df['total_bill'], bins=20, kde=True)
plt.title('Total Bill Distribution')
plt.show()

# %% [markdown]
# ## Box Plot
# Box plots are useful for visualizing data distributions and outliers.

# %%
sns.boxplot(x='day', y='total_bill', data=df)
plt.title('Total Bill by Day')
plt.show()

# %% [markdown]
# ## Pairplot
# Pair plots show pairwise relationships in a dataset.

# %%
sns.pairplot(df, hue='sex')
plt.show()

# %% [markdown]
# ## Correlation Heatmap
# Heatmaps show relationships between numerical variables.

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\veera\AppData\Local\Temp\ipykernel_21536\3313091386.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
